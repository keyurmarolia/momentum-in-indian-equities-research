# %% [markdown]
# # Cross-strategy findings
#
# The comparisons hold the other design dimensions fixed and keep the academic long-short result separate from taxable long-only portfolios.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))
from momentum_india.notebook_views import ResearchNotebook

research = ResearchNotebook()
# Out:
# <style>.research-table{border-collapse:collapse;font-size:13px;width:100%;max-width:1040px}.research-table th,.research-table td{padding:8px 10px;text-align:left;border-bottom:1px solid #dfe4e8;white-space:normal;max-width:220px}.research-table th{background:#edf1f4;color:#22313f}.jp-OutputArea-output{overflow-x:auto}</style>

# %% [markdown]
# ## Questions answered
#
# - Does raw momentum remain positive after the modeled frictions?
# - Do volatility scaling and Jensen alpha improve matched raw-momentum outcomes?
# - Does KM's technical filter and exit-to-cash rule improve risk-adjusted returns?
# - How do six/twelve-month formation, rebalance speed and breadth change performance?
# - Does winner drift improve the equal-weight trade-off?
# - Does the academic winner-minus-loser portfolio remain positive after fixed borrowing deductions?

# %%
research.findings()
# Out:
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> All 180 portfolios are measured from 02 Jul 2007 to 28 Aug 2026, rebased at the start of this shared measurement window. Holdings retain their actual earlier history. Long-only results include the tax overlay. JT* is an academic long-short reference with 6% annual borrowing, not a taxable executable alternative.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> Each tile is one portfolio, not an average. Columns pair rebalance frequency with EW (equal-weight reset) or WD (winner drift); rows identify the strategy. The same color scale applies to all six panels for the selected metric. Green denotes the favorable direction, not statistical significance.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> KM Momentum has the best mean CAGR across its 36 matched long-only configurations (13.0%). This summarizes separate portfolios; it is not the performance of a combined fund.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> Each tile is one portfolio, not an average. Columns pair rebalance frequency with EW (equal-weight reset) or WD (winner drift); rows identify the strategy. The same color scale applies to all six panels for the selected metric. Green denotes the favorable direction, not statistical significance.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> KM Momentum has the best mean Max drawdown across its 36 matched long-only configurations (-36.8%). This summarizes separate portfolios; it is not the performance of a combined fund.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> Each tile is one portfolio, not an average. Columns pair rebalance frequency with EW (equal-weight reset) or WD (winner drift); rows identify the strategy. The same color scale applies to all six panels for the selected metric. Green denotes the favorable direction, not statistical significance.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> KM Momentum has the best mean Sharpe across its 36 matched long-only configurations (0.44). This summarizes separate portfolios; it is not the performance of a combined fund.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> Mean daily drawdown averages the distance below the running peak over all sessions, including peaks at zero. Time underwater is the fraction below that peak, not the fraction of loss-making days. VaR is the historical 95% monthly loss quantile; partial boundary months are included. Calmar is CAGR divided by maximum drawdown magnitude. Sharpe uses daily excess returns over the liquid-fund proxy. No arbitrary risk/reward score is used.</div>
# <p><a href='../reports/tables/matched_strategy_comparison.csv'>All 180 matched configurations and metrics (CSV)</a></p>
# <p><b>Mean post-tax statistics across matched long-only cells</b></p><div style='overflow-x:auto'><table class="dataframe research-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Strategy</th>
#       <th>CAGR</th>
#       <th>Sharpe</th>
#       <th>Max drawdown</th>
#       <th>Monthly VaR 95%</th>
#       <th>Monthly ES 95%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Jensen Alpha Momentum</td>
#       <td>9.5%</td>
#       <td>0.212</td>
#       <td>-78.2%</td>
#       <td>10.0%</td>
#       <td>17.0%</td>
#     </tr>
#     <tr>
#       <td>KM Momentum</td>
#       <td>13.0%</td>
#       <td>0.436</td>
#       <td>-36.8%</td>
#       <td>6.1%</td>
#       <td>8.6%</td>
#     </tr>
#     <tr>
#       <td>Raw Momentum</td>
#       <td>9.6%</td>
#       <td>0.218</td>
#       <td>-74.7%</td>
#       <td>9.5%</td>
#       <td>16.3%</td>
#     </tr>
#     <tr>
#       <td>Volatility-Adjusted Momentum</td>
#       <td>11.7%</td>
#       <td>0.321</td>
#       <td>-69.4%</td>
#       <td>8.4%</td>
#       <td>14.6%</td>
#     </tr>
#   </tbody>
# </table></div>
# <p><b>Average recovery burden across the same cells</b></p><div style='overflow-x:auto'><table class="dataframe research-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Strategy</th>
#       <th>Time below prior peak</th>
#       <th>Longest underwater (sessions)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Jensen Alpha Momentum</td>
#       <td>94.6%</td>
#       <td>1,899.97</td>
#     </tr>
#     <tr>
#       <td>KM Momentum</td>
#       <td>92.7%</td>
#       <td>877.50</td>
#     </tr>
#     <tr>
#       <td>Raw Momentum</td>
#       <td>94.4%</td>
#       <td>1,903.61</td>
#     </tr>
#     <tr>
#       <td>Volatility-Adjusted Momentum</td>
#       <td>92.9%</td>
#       <td>1,667.67</td>
#     </tr>
#   </tbody>
# </table></div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> The mean longest episode is an average across portfolios, not one continuous combined episode. Time underwater measures waiting for a previous peak to be recovered; it does not count negative days.</div>
# <div style='background:#e8f4eb;border-left:4px solid #287745;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> Volatility-Adjusted Momentum versus Raw Momentum: mean CAGR difference +2.11%; higher Sharpe in 94% of matched cells; mean drawdown difference +5.32%.</div>
# <div style='background:#fceced;border-left:4px solid #ab3438;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> Jensen Alpha Momentum versus Raw Momentum: mean CAGR difference -0.07%; higher Sharpe in 47% of matched cells; mean drawdown difference -3.53%.</div>
# <div style='background:#e8f4eb;border-left:4px solid #287745;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> KM Momentum versus Raw Momentum: mean CAGR difference +3.37%; higher Sharpe in 75% of matched cells; mean drawdown difference +37.93%.</div>
# <p><b>Matched grid summary: Lookback</b></p><div style='overflow-x:auto'><table class="dataframe research-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Lookback</th>
#       <th>CAGR</th>
#       <th>Sharpe</th>
#       <th>Max drawdown</th>
#       <th>Monthly VaR 95%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>6M</td>
#       <td>10.9%</td>
#       <td>0.295</td>
#       <td>-65.7%</td>
#       <td>8.5%</td>
#     </tr>
#     <tr>
#       <td>12M</td>
#       <td>11.0%</td>
#       <td>0.298</td>
#       <td>-63.8%</td>
#       <td>8.6%</td>
#     </tr>
#   </tbody>
# </table></div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> 12M has the highest average Sharpe (0.30) in this dimension. These balanced averages cover the same other settings and shared measurement dates; individual portfolios can show the opposite ordering.</div>
# <p><b>Matched grid summary: Rebalance</b></p><div style='overflow-x:auto'><table class="dataframe research-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Rebalance</th>
#       <th>CAGR</th>
#       <th>Sharpe</th>
#       <th>Max drawdown</th>
#       <th>Monthly VaR 95%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1M</td>
#       <td>11.8%</td>
#       <td>0.341</td>
#       <td>-69.2%</td>
#       <td>8.7%</td>
#     </tr>
#     <tr>
#       <td>3M</td>
#       <td>12.6%</td>
#       <td>0.394</td>
#       <td>-64.3%</td>
#       <td>8.6%</td>
#     </tr>
#     <tr>
#       <td>6M</td>
#       <td>8.4%</td>
#       <td>0.155</td>
#       <td>-60.8%</td>
#       <td>8.2%</td>
#     </tr>
#   </tbody>
# </table></div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> 3M has the highest average Sharpe (0.39) in this dimension. These balanced averages cover the same other settings and shared measurement dates; individual portfolios can show the opposite ordering.</div>
# <p><b>Matched grid summary: N</b></p><div style='overflow-x:auto'><table class="dataframe research-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>N</th>
#       <th>CAGR</th>
#       <th>Sharpe</th>
#       <th>Max drawdown</th>
#       <th>Monthly VaR 95%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>12</td>
#       <td>9.8%</td>
#       <td>0.224</td>
#       <td>-66.5%</td>
#       <td>9.0%</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>11.2%</td>
#       <td>0.307</td>
#       <td>-64.4%</td>
#       <td>8.4%</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>11.9%</td>
#       <td>0.360</td>
#       <td>-63.3%</td>
#       <td>8.1%</td>
#     </tr>
#   </tbody>
# </table></div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> 50 has the highest average Sharpe (0.36) in this dimension. These balanced averages cover the same other settings and shared measurement dates; individual portfolios can show the opposite ordering.</div>
# <p><b>Matched grid summary: Maintenance</b></p><div style='overflow-x:auto'><table class="dataframe research-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Maintenance</th>
#       <th>CAGR</th>
#       <th>Sharpe</th>
#       <th>Max drawdown</th>
#       <th>Monthly VaR 95%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>equal_weight</td>
#       <td>11.5%</td>
#       <td>0.317</td>
#       <td>-66.0%</td>
#       <td>9.6%</td>
#     </tr>
#     <tr>
#       <td>winner_drift</td>
#       <td>10.4%</td>
#       <td>0.277</td>
#       <td>-63.5%</td>
#       <td>7.4%</td>
#     </tr>
#   </tbody>
# </table></div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> equal_weight has the highest average Sharpe (0.32) in this dimension. These balanced averages cover the same other settings and shared measurement dates; individual portfolios can show the opposite ordering.</div>
# <p><b>Academic factor at the 6% borrowing assumption</b></p><div style='overflow-x:auto'><table class="dataframe research-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Lookback</th>
#       <th>Maintenance</th>
#       <th>CAGR</th>
#       <th>Sharpe</th>
#       <th>Max drawdown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>12M</td>
#       <td>equal_weight</td>
#       <td>20.6%</td>
#       <td>0.803</td>
#       <td>-62.5%</td>
#     </tr>
#     <tr>
#       <td>12M</td>
#       <td>winner_drift</td>
#       <td>20.6%</td>
#       <td>0.791</td>
#       <td>-63.5%</td>
#     </tr>
#     <tr>
#       <td>6M</td>
#       <td>equal_weight</td>
#       <td>20.5%</td>
#       <td>0.806</td>
#       <td>-56.6%</td>
#     </tr>
#     <tr>
#       <td>6M</td>
#       <td>winner_drift</td>
#       <td>20.7%</td>
#       <td>0.814</td>
#       <td>-56.2%</td>
#     </tr>
#   </tbody>
# </table></div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> 36/36 academic cells have positive compound returns. They include collateral/cash earnings and therefore do not by themselves prove a pure winner-minus-loser alpha.</div>
# <div style='background:#f2f4f7;border-left:4px solid #59636e;padding:10px 14px;margin:12px 0;color:#202a32'><b>Observation.</b> 144/144 long-only cells remain positive after the modeled tax overlay. This is evidence about the observed sample and stated assumptions, not proof of a behavioral cause. No holdout test or multiple-testing correction is claimed.</div>

# %% [markdown]
# ## Meaning of the evidence
#
# The study compares signal behavior, portfolio construction and realized risk—not only terminal wealth. It does not identify a causal behavioral explanation, establish statistical significance across a searched grid or demonstrate out-of-sample persistence. Corporate-action coverage, suspended-position valuation, delisting recovery and tax-overlay assumptions remain part of every result.
